# %%
import scanpy
import scanpy.api as sc
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=70)  # dots (pixels) per inch determine size of inline figures
sc.settings.cachedir='/home/mt/Downloads/macaquecache'
sc.logging.print_versions()
import pandas as pd
import numpy as np
import re
from collections import Counter
import seaborn
import matplotlib.pyplot as plt
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import os
import anndata
# Out:
# scanpy==1.4.1+48.g73f1e6a anndata==0.6.19 umap==0.3.8 numpy==1.16.2 scipy==1.2.1 pandas==0.24.2 scikit-learn==0.20.3 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
mskey=pd.read_csv('/home/mt/Downloads/MULTIseqOutputs/MultiseqKey.txt',sep='\t')
fullname=[]
mskey=mskey.astype(str,copy=True)
for i in range(mskey.shape[0]):
    if "nan" not in mskey.iloc[i,2] :
        fullname.append(mskey.iloc[i,1]+"_"+mskey.iloc[i,2]+"_"+mskey.iloc[i,3])
    else:
        fullname.append(mskey.iloc[i,1]+"_"+str(mskey.iloc[i,3]))
mskey['fullname']=fullname

# %%
mskey
# Out:
#    Unnamed: 0 Timepoint\n Individual         Sample Multiseq Index  \
# 0           1         E80        nan            PFC              2
# 1           2         E80        nan        Motor-1             10
# 2           3         E80        nan           Pons             18
# 3           4         E80        nan         Somato             26
# 4           5         E80        nan       Parietal             34
# 5           6         E80        nan       Temporal             42
# 6           7         E80        nan             V1              4
# 7           8         E80        nan          Hippo             12
# 8           9         E80        nan        Choroid             20
# 9          10         E80        nan            MGE             28
# 10         11         E80        nan            LGE             36
# 11         12         E80        nan            CGE             44
# 12         13         E80        nan       Thalamus              3
# 13         14         E80        nan   Hypothalamus             11
# 14         15         E80        nan       Midbrain             19
# 15         16         E80        nan     Cerebellum             27
# 16          1         E90        nan            PFC              9
# 17          2         E90        nan        Motor-1             10
# 18          3         E90        nan        Motor-2             11
# 19          4         E90        nan         Somato             12
# 20          5         E90        nan       Parietal             13
# 21          6         E90        nan       Temporal             14
# 22          7         E90        nan             V1             15
# 23          8         E90        nan          Hippo             16
# 24          9         E90        nan        Choroid             17
# 25         10         E90        nan            MGE             18
# 26         11         E90        nan            LGE             19
# 27         12         E90        nan            CGE             20
# 28         13         E90        nan        Putamen             21
# 29         14         E90        nan         Septum             22
# ..        ...         ...        ...            ...            ...
# 38          3         E65          A             V1             35
# 39          4         E65          A            MGE             36
# 40          5         E65          B            PFC             37
# 41          6         E65          B        Motor-1             38
# 42          7         E65          B             V1             39
# 43          8         E65          B            MGE             40
# 44          9         E65          A        Motor-2             41
# 45         10         E65          B        Motor-2             42
# 46         11         E65          A            LGE             43
# 47         12         E65          A            CGE             44
# 48         13         E65          A         Somato             45
# 49         14         E65          A           Thal             46
# 50         15         E65          A           Hypo             47
# 51         16         E65          A       Temporal             48
# 52         17         E65          A       Parietal             49
# 53         18         E65          A           Pons             50
# 54         19         E65          A     Cerebellum             51
# 55         20         E65          A       Midbrain             52
# 56         21         E65          B       Thalamus             53
# 57         22         E65          B   Hypothalamus             54
# 58         23         E65          A    Hippocampus             55
# 59         24         E65          B            LGE             56
# 60         25         E65          B     Cerebellum             57
# 61         26         E65          B       Temporal             58
# 62         27         E65          B       Parietal             59
# 63         28         E65          B         Somato             60
# 64         29         E65          B    Hippocampus             61
# 65         30         E65          B        Choroid             62
# 66         31         E65          A        Choroid             63
# 67         32         E65          B  Midbrain/Pons             64
#
#    P7IlluminaIndexNumber             fullname
# 0                      1              E80_PFC
# 1                      1          E80_Motor-1
# 2                      1             E80_Pons
# 3                      1           E80_Somato
# 4                      1         E80_Parietal
# 5                      1         E80_Temporal
# 6                      1               E80_V1
# 7                      1            E80_Hippo
# 8                      1          E80_Choroid
# 9                      1              E80_MGE
# 10                     1              E80_LGE
# 11                     1              E80_CGE
# 12                     1         E80_Thalamus
# 13                     1     E80_Hypothalamus
# 14                     1         E80_Midbrain
# 15                     1       E80_Cerebellum
# 16                     2              E90_PFC
# 17                     2          E90_Motor-1
# 18                     2          E90_Motor-2
# 19                     2           E90_Somato
# 20                     2         E90_Parietal
# 21                     2         E90_Temporal
# 22                     2               E90_V1
# 23                     2            E90_Hippo
# 24                     2          E90_Choroid
# 25                     2              E90_MGE
# 26                     2              E90_LGE
# 27                     2              E90_CGE
# 28                     2          E90_Putamen
# 29                     2           E90_Septum
# ..                   ...                  ...
# 38                 3,4,5             E65_A_V1
# 39                 3,4,5            E65_A_MGE
# 40                 3,4,5            E65_B_PFC
# 41                 3,4,5        E65_B_Motor-1
# 42                 3,4,5             E65_B_V1
# 43                 3,4,5            E65_B_MGE
# 44                 3,4,5        E65_A_Motor-2
# 45                 3,4,5        E65_B_Motor-2
# 46                 3,4,5            E65_A_LGE
# 47                 3,4,5            E65_A_CGE
# 48                 3,4,5         E65_A_Somato
# 49                 3,4,5           E65_A_Thal
# 50                 3,4,5           E65_A_Hypo
# 51                 3,4,5       E65_A_Temporal
# 52                 3,4,5       E65_A_Parietal
# 53                 3,4,5           E65_A_Pons
# 54                 3,4,5     E65_A_Cerebellum
# 55                 3,4,5       E65_A_Midbrain
# 56                 3,4,5       E65_B_Thalamus
# 57                 3,4,5   E65_B_Hypothalamus
# 58                 3,4,5    E65_A_Hippocampus
# 59                 3,4,5            E65_B_LGE
# 60                 3,4,5     E65_B_Cerebellum
# 61                 3,4,5       E65_B_Temporal
# 62                 3,4,5       E65_B_Parietal
# 63                 3,4,5         E65_B_Somato
# 64                 3,4,5    E65_B_Hippocampus
# 65                 3,4,5        E65_B_Choroid
# 66                 3,4,5        E65_A_Choroid
# 67                 3,4,5  E65_B_Midbrain/Pons
#
# [68 rows x 7 columns]

# %%
samples=["E65-1","E65-2","E65-3","E80","E90"]
sampletable={}
for s in samples:
    sampletable[s]=pd.read_csv('/home/mt/Downloads/MULTIseqOutputs/pollena-MULTIseq_'+s+'_finalcalls.txt',sep='\t').T

for s in sampletable.keys():
    sampletable[s].iloc[:,0]=[re.sub("Bar","",x) for x in sampletable[s].iloc[:,0]]

IndConversion=pd.read_csv('/home/mt/Downloads/MULTIseqOutputs/8-12IndexConversion.txt',sep='\t')
IndConversion=IndConversion.astype(str,copy=True)
ICdict=dict(zip(IndConversion["8-Index"],IndConversion["12-Index"]))
ICdict['Doublet']='Doublet'
ICdict['Negative']='Negative'

mskey.iloc[:,4]=[ICdict[x] for x in mskey.iloc[:,4]]

#for s in sampletable.keys():
#    sampletable[s].iloc[:,0]=[ICdict[x] for x in sampletable[s].iloc[:,0]]

# %%
mskey
# Out:
#    Unnamed: 0 Timepoint\n Individual         Sample Multiseq Index  \
# 0           1         E80        nan            PFC             13
# 1           2         E80        nan        Motor-1             14
# 2           3         E80        nan           Pons             15
# 3           4         E80        nan         Somato             16
# 4           5         E80        nan       Parietal             17
# 5           6         E80        nan       Temporal             18
# 6           7         E80        nan             V1             37
# 7           8         E80        nan          Hippo             38
# 8           9         E80        nan        Choroid             39
# 9          10         E80        nan            MGE             40
# 10         11         E80        nan            LGE             41
# 11         12         E80        nan            CGE             42
# 12         13         E80        nan       Thalamus             25
# 13         14         E80        nan   Hypothalamus             26
# 14         15         E80        nan       Midbrain             27
# 15         16         E80        nan     Cerebellum             28
# 16          1         E90        nan            PFC              2
# 17          2         E90        nan        Motor-1             14
# 18          3         E90        nan        Motor-2             26
# 19          4         E90        nan         Somato             38
# 20          5         E90        nan       Parietal             50
# 21          6         E90        nan       Temporal             62
# 22          7         E90        nan             V1             74
# 23          8         E90        nan          Hippo             86
# 24          9         E90        nan        Choroid              3
# 25         10         E90        nan            MGE             15
# 26         11         E90        nan            LGE             27
# 27         12         E90        nan            CGE             39
# 28         13         E90        nan        Putamen             51
# 29         14         E90        nan         Septum             63
# ..        ...         ...        ...            ...            ...
# 38          3         E65          A             V1             29
# 39          4         E65          A            MGE             41
# 40          5         E65          B            PFC             53
# 41          6         E65          B        Motor-1             65
# 42          7         E65          B             V1             77
# 43          8         E65          B            MGE             89
# 44          9         E65          A        Motor-2              6
# 45         10         E65          B        Motor-2             18
# 46         11         E65          A            LGE             30
# 47         12         E65          A            CGE             42
# 48         13         E65          A         Somato             54
# 49         14         E65          A           Thal             66
# 50         15         E65          A           Hypo             78
# 51         16         E65          A       Temporal             90
# 52         17         E65          A       Parietal              7
# 53         18         E65          A           Pons             19
# 54         19         E65          A     Cerebellum             31
# 55         20         E65          A       Midbrain             43
# 56         21         E65          B       Thalamus             55
# 57         22         E65          B   Hypothalamus             67
# 58         23         E65          A    Hippocampus             79
# 59         24         E65          B            LGE             91
# 60         25         E65          B     Cerebellum              8
# 61         26         E65          B       Temporal             20
# 62         27         E65          B       Parietal             32
# 63         28         E65          B         Somato             44
# 64         29         E65          B    Hippocampus             56
# 65         30         E65          B        Choroid             68
# 66         31         E65          A        Choroid             80
# 67         32         E65          B  Midbrain/Pons             92
#
#    P7IlluminaIndexNumber             fullname
# 0                      1              E80_PFC
# 1                      1          E80_Motor-1
# 2                      1             E80_Pons
# 3                      1           E80_Somato
# 4                      1         E80_Parietal
# 5                      1         E80_Temporal
# 6                      1               E80_V1
# 7                      1            E80_Hippo
# 8                      1          E80_Choroid
# 9                      1              E80_MGE
# 10                     1              E80_LGE
# 11                     1              E80_CGE
# 12                     1         E80_Thalamus
# 13                     1     E80_Hypothalamus
# 14                     1         E80_Midbrain
# 15                     1       E80_Cerebellum
# 16                     2              E90_PFC
# 17                     2          E90_Motor-1
# 18                     2          E90_Motor-2
# 19                     2           E90_Somato
# 20                     2         E90_Parietal
# 21                     2         E90_Temporal
# 22                     2               E90_V1
# 23                     2            E90_Hippo
# 24                     2          E90_Choroid
# 25                     2              E90_MGE
# 26                     2              E90_LGE
# 27                     2              E90_CGE
# 28                     2          E90_Putamen
# 29                     2           E90_Septum
# ..                   ...                  ...
# 38                 3,4,5             E65_A_V1
# 39                 3,4,5            E65_A_MGE
# 40                 3,4,5            E65_B_PFC
# 41                 3,4,5        E65_B_Motor-1
# 42                 3,4,5             E65_B_V1
# 43                 3,4,5            E65_B_MGE
# 44                 3,4,5        E65_A_Motor-2
# 45                 3,4,5        E65_B_Motor-2
# 46                 3,4,5            E65_A_LGE
# 47                 3,4,5            E65_A_CGE
# 48                 3,4,5         E65_A_Somato
# 49                 3,4,5           E65_A_Thal
# 50                 3,4,5           E65_A_Hypo
# 51                 3,4,5       E65_A_Temporal
# 52                 3,4,5       E65_A_Parietal
# 53                 3,4,5           E65_A_Pons
# 54                 3,4,5     E65_A_Cerebellum
# 55                 3,4,5       E65_A_Midbrain
# 56                 3,4,5       E65_B_Thalamus
# 57                 3,4,5   E65_B_Hypothalamus
# 58                 3,4,5    E65_A_Hippocampus
# 59                 3,4,5            E65_B_LGE
# 60                 3,4,5     E65_B_Cerebellum
# 61                 3,4,5       E65_B_Temporal
# 62                 3,4,5       E65_B_Parietal
# 63                 3,4,5         E65_B_Somato
# 64                 3,4,5    E65_B_Hippocampus
# 65                 3,4,5        E65_B_Choroid
# 66                 3,4,5        E65_A_Choroid
# 67                 3,4,5  E65_B_Midbrain/Pons
#
# [68 rows x 7 columns]

# %%
for s in sampletable.keys():
    data = [go.Bar(
        y=sampletable[s][1].value_counts().to_dense().keys(),
        x=sampletable[s][1].value_counts(),
        orientation='h',
        text="",
    )]
    layout = go.Layout(
    title=go.layout.Title(
        text=s,
        xref='paper',
        x=0
    ))
    fig = go.Figure(data=data, layout=layout)
    iplot(fig, show_link=False)
    print(sorted(Counter(sampletable[s][1])))
# Out:
# <div>
#
#
#             <div id="55b1037f-0b28-4c18-9ed7-6a049b204c9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("55b1037f-0b28-4c18-9ed7-6a049b204c9c")) {
#                     Plotly.newPlot(
#                         '55b1037f-0b28-4c18-9ed7-6a049b204c9c',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "42565d8b-a6af-450f-a556-99efec34bf06", "x": [2364, 469, 420, 321, 299, 279, 253, 228, 184, 168, 159, 158, 152, 146, 142, 125, 123, 114, 110, 109, 109, 109, 103, 91, 83, 80, 76, 73, 48, 41, 35, 26, 12, 11, 3, 1], "y": ["Negative", "18", "Doublet", "90", "29", "42", "54", "32", "89", "53", "5", "65", "17", "30", "66", "77", "44", "7", "78", "20", "41", "6", "68", "79", "43", "80", "55", "8", "91", "31", "56", "19", "92", "67", "73", "93"]}],
#                         {"title": {"text": "E65-1", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('55b1037f-0b28-4c18-9ed7-6a049b204c9c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['17', '18', '19', '20', '29', '30', '31', '32', '41', '42', '43', '44', '5', '53', '54', '55', '56', '6', '65', '66', '67', '68', '7', '73', '77', '78', '79', '8', '80', '89', '90', '91', '92', '93', 'Doublet', 'Negative']
# <div>
#
#
#             <div id="b1fa9a2f-f3bd-4fe6-9f4d-9dce384dc802" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b1fa9a2f-f3bd-4fe6-9f4d-9dce384dc802")) {
#                     Plotly.newPlot(
#                         'b1fa9a2f-f3bd-4fe6-9f4d-9dce384dc802',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "bcbaea8b-9391-40ea-bfd9-8431a1e37796", "x": [4783, 4330, 645, 503, 372, 360, 324, 296, 266, 233, 210, 208, 208, 205, 205, 202, 181, 173, 173, 141, 133, 128, 127, 121, 117, 116, 111, 101, 94, 74, 72, 45, 30, 19, 17, 17, 9, 3, 3, 1, 1, 1, 1], "y": ["Negative", "Doublet", "18", "90", "31", "29", "42", "54", "32", "17", "65", "78", "30", "44", "89", "53", "77", "68", "5", "7", "66", "43", "6", "79", "41", "8", "20", "55", "80", "56", "91", "19", "92", "67", "75", "74", "12", "73", "82", "46", "93", "23", "84"]}],
#                         {"title": {"text": "E65-2", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('b1fa9a2f-f3bd-4fe6-9f4d-9dce384dc802');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['12', '17', '18', '19', '20', '23', '29', '30', '31', '32', '41', '42', '43', '44', '46', '5', '53', '54', '55', '56', '6', '65', '66', '67', '68', '7', '73', '74', '75', '77', '78', '79', '8', '80', '82', '84', '89', '90', '91', '92', '93', 'Doublet', 'Negative']
# <div>
#
#
#             <div id="06fabe69-a6df-4136-8bc2-672df3f3d083" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("06fabe69-a6df-4136-8bc2-672df3f3d083")) {
#                     Plotly.newPlot(
#                         '06fabe69-a6df-4136-8bc2-672df3f3d083',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "ead2497c-33d4-4a92-9b5f-b3130805d2e2", "x": [4575, 2086, 861, 588, 496, 469, 440, 397, 293, 281, 278, 276, 274, 272, 270, 264, 232, 232, 222, 212, 208, 198, 190, 173, 166, 146, 138, 125, 122, 119, 84, 43, 25, 23, 9, 6, 3, 1], "y": ["Negative", "Doublet", "18", "90", "42", "29", "54", "32", "53", "66", "89", "30", "44", "17", "78", "5", "77", "65", "68", "41", "7", "43", "20", "79", "80", "6", "55", "8", "56", "31", "91", "19", "92", "67", "12", "82", "61", "93"]}],
#                         {"title": {"text": "E65-3", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('06fabe69-a6df-4136-8bc2-672df3f3d083');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['12', '17', '18', '19', '20', '29', '30', '31', '32', '41', '42', '43', '44', '5', '53', '54', '55', '56', '6', '61', '65', '66', '67', '68', '7', '77', '78', '79', '8', '80', '82', '89', '90', '91', '92', '93', 'Doublet', 'Negative']
# <div>
#
#
#             <div id="eaf935e2-4d9d-4af5-aa0c-04cfe440e3c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eaf935e2-4d9d-4af5-aa0c-04cfe440e3c7")) {
#                     Plotly.newPlot(
#                         'eaf935e2-4d9d-4af5-aa0c-04cfe440e3c7',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "09dfafe8-7ea0-435b-9bf8-083267b2a7b5", "x": [5716, 4842, 1033, 720, 496, 447, 438, 364, 344, 317, 248, 235, 228, 226, 212, 131, 122, 106], "y": ["Doublet", "Negative", "42", "26", "16", "15", "39", "27", "14", "40", "28", "41", "25", "38", "17", "18", "13", "37"]}],
#                         {"title": {"text": "E80", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('eaf935e2-4d9d-4af5-aa0c-04cfe440e3c7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['13', '14', '15', '16', '17', '18', '25', '26', '27', '28', '37', '38', '39', '40', '41', '42', 'Doublet', 'Negative']
# <div>
#
#
#             <div id="3842e881-4f10-4b09-8f8c-2a9af18e3e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3842e881-4f10-4b09-8f8c-2a9af18e3e20")) {
#                     Plotly.newPlot(
#                         '3842e881-4f10-4b09-8f8c-2a9af18e3e20',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "474793fd-1ac3-486d-9888-60d52fd365bb", "x": [3908, 2234, 1154, 778, 630, 531, 473, 470, 450, 442, 379, 371, 347, 306, 224, 201, 177, 133, 106, 54, 18, 12, 9, 6, 1], "y": ["Negative", "Doublet", "26", "15", "51", "3", "27", "14", "87", "75", "39", "88", "38", "86", "2", "50", "64", "52", "62", "74", "63", "82", "46", "66", "53"]}],
#                         {"title": {"text": "E90", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('3842e881-4f10-4b09-8f8c-2a9af18e3e20');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['14', '15', '2', '26', '27', '3', '38', '39', '46', '50', '51', '52', '53', '62', '63', '64', '66', '74', '75', '82', '86', '87', '88', 'Doublet', 'Negative']

# %%
sampleregions={}
for s in sampletable.keys():
    curkey=mskey.iloc[[x in s for x in mskey.iloc[:,1]],:]
    curkeydict=dict(zip(curkey.iloc[:,4],curkey.iloc[:,6]))
    print(curkey)
    samplematched=[]
    for i in sampletable[s].iloc[:,0]:
        inds=np.where([x == i for x in curkey.iloc[:,4]])[0]
        if len(inds)<1:
            samplematched.append(i)
        else:
            samplematched.append(curkey.iat[ inds[0] ,6])
    sampletable[s].iloc[:,0]=samplematched
# Out:
#    Unnamed: 0 Timepoint\n Individual         Sample Multiseq Index  \
# 36          1         E65          A            PFC              5
# 37          2         E65          A        Motor-1             17
# 38          3         E65          A             V1             29
# 39          4         E65          A            MGE             41
# 40          5         E65          B            PFC             53
# 41          6         E65          B        Motor-1             65
# 42          7         E65          B             V1             77
# 43          8         E65          B            MGE             89
# 44          9         E65          A        Motor-2              6
# 45         10         E65          B        Motor-2             18
# 46         11         E65          A            LGE             30
# 47         12         E65          A            CGE             42
# 48         13         E65          A         Somato             54
# 49         14         E65          A           Thal             66
# 50         15         E65          A           Hypo             78
# 51         16         E65          A       Temporal             90
# 52         17         E65          A       Parietal              7
# 53         18         E65          A           Pons             19
# 54         19         E65          A     Cerebellum             31
# 55         20         E65          A       Midbrain             43
# 56         21         E65          B       Thalamus             55
# 57         22         E65          B   Hypothalamus             67
# 58         23         E65          A    Hippocampus             79
# 59         24         E65          B            LGE             91
# 60         25         E65          B     Cerebellum              8
# 61         26         E65          B       Temporal             20
# 62         27         E65          B       Parietal             32
# 63         28         E65          B         Somato             44
# 64         29         E65          B    Hippocampus             56
# 65         30         E65          B        Choroid             68
# 66         31         E65          A        Choroid             80
# 67         32         E65          B  Midbrain/Pons             92
#
#    P7IlluminaIndexNumber             fullname
# 36                 3,4,5            E65_A_PFC
# 37                 3,4,5        E65_A_Motor-1
# 38                 3,4,5             E65_A_V1
# 39                 3,4,5            E65_A_MGE
# 40                 3,4,5            E65_B_PFC
# 41                 3,4,5        E65_B_Motor-1
# 42                 3,4,5             E65_B_V1
# 43                 3,4,5            E65_B_MGE
# 44                 3,4,5        E65_A_Motor-2
# 45                 3,4,5        E65_B_Motor-2
# 46                 3,4,5            E65_A_LGE
# 47                 3,4,5            E65_A_CGE
# 48                 3,4,5         E65_A_Somato
# 49                 3,4,5           E65_A_Thal
# 50                 3,4,5           E65_A_Hypo
# 51                 3,4,5       E65_A_Temporal
# 52                 3,4,5       E65_A_Parietal
# 53                 3,4,5           E65_A_Pons
# 54                 3,4,5     E65_A_Cerebellum
# 55                 3,4,5       E65_A_Midbrain
# 56                 3,4,5       E65_B_Thalamus
# 57                 3,4,5   E65_B_Hypothalamus
# 58                 3,4,5    E65_A_Hippocampus
# 59                 3,4,5            E65_B_LGE
# 60                 3,4,5     E65_B_Cerebellum
# 61                 3,4,5       E65_B_Temporal
# 62                 3,4,5       E65_B_Parietal
# 63                 3,4,5         E65_B_Somato
# 64                 3,4,5    E65_B_Hippocampus
# 65                 3,4,5        E65_B_Choroid
# 66                 3,4,5        E65_A_Choroid
# 67                 3,4,5  E65_B_Midbrain/Pons
#    Unnamed: 0 Timepoint\n Individual         Sample Multiseq Index  \
# 36          1         E65          A            PFC              5
# 37          2         E65          A        Motor-1             17
# 38          3         E65          A             V1             29
# 39          4         E65          A            MGE             41
# 40          5         E65          B            PFC             53
# 41          6         E65          B        Motor-1             65
# 42          7         E65          B             V1             77
# 43          8         E65          B            MGE             89
# 44          9         E65          A        Motor-2              6
# 45         10         E65          B        Motor-2             18
# 46         11         E65          A            LGE             30
# 47         12         E65          A            CGE             42
# 48         13         E65          A         Somato             54
# 49         14         E65          A           Thal             66
# 50         15         E65          A           Hypo             78
# 51         16         E65          A       Temporal             90
# 52         17         E65          A       Parietal              7
# 53         18         E65          A           Pons             19
# 54         19         E65          A     Cerebellum             31
# 55         20         E65          A       Midbrain             43
# 56         21         E65          B       Thalamus             55
# 57         22         E65          B   Hypothalamus             67
# 58         23         E65          A    Hippocampus             79
# 59         24         E65          B            LGE             91
# 60         25         E65          B     Cerebellum              8
# 61         26         E65          B       Temporal             20
# 62         27         E65          B       Parietal             32
# 63         28         E65          B         Somato             44
# 64         29         E65          B    Hippocampus             56
# 65         30         E65          B        Choroid             68
# 66         31         E65          A        Choroid             80
# 67         32         E65          B  Midbrain/Pons             92
#
#    P7IlluminaIndexNumber             fullname
# 36                 3,4,5            E65_A_PFC
# 37                 3,4,5        E65_A_Motor-1
# 38                 3,4,5             E65_A_V1
# 39                 3,4,5            E65_A_MGE
# 40                 3,4,5            E65_B_PFC
# 41                 3,4,5        E65_B_Motor-1
# 42                 3,4,5             E65_B_V1
# 43                 3,4,5            E65_B_MGE
# 44                 3,4,5        E65_A_Motor-2
# 45                 3,4,5        E65_B_Motor-2
# 46                 3,4,5            E65_A_LGE
# 47                 3,4,5            E65_A_CGE
# 48                 3,4,5         E65_A_Somato
# 49                 3,4,5           E65_A_Thal
# 50                 3,4,5           E65_A_Hypo
# 51                 3,4,5       E65_A_Temporal
# 52                 3,4,5       E65_A_Parietal
# 53                 3,4,5           E65_A_Pons
# 54                 3,4,5     E65_A_Cerebellum
# 55                 3,4,5       E65_A_Midbrain
# 56                 3,4,5       E65_B_Thalamus
# 57                 3,4,5   E65_B_Hypothalamus
# 58                 3,4,5    E65_A_Hippocampus
# 59                 3,4,5            E65_B_LGE
# 60                 3,4,5     E65_B_Cerebellum
# 61                 3,4,5       E65_B_Temporal
# 62                 3,4,5       E65_B_Parietal
# 63                 3,4,5         E65_B_Somato
# 64                 3,4,5    E65_B_Hippocampus
# 65                 3,4,5        E65_B_Choroid
# 66                 3,4,5        E65_A_Choroid
# 67                 3,4,5  E65_B_Midbrain/Pons
#    Unnamed: 0 Timepoint\n Individual         Sample Multiseq Index  \
# 36          1         E65          A            PFC              5
# 37          2         E65          A        Motor-1             17
# 38          3         E65          A             V1             29
# 39          4         E65          A            MGE             41
# 40          5         E65          B            PFC             53
# 41          6         E65          B        Motor-1             65
# 42          7         E65          B             V1             77
# 43          8         E65          B            MGE             89
# 44          9         E65          A        Motor-2              6
# 45         10         E65          B        Motor-2             18
# 46         11         E65          A            LGE             30
# 47         12         E65          A            CGE             42
# 48         13         E65          A         Somato             54
# 49         14         E65          A           Thal             66
# 50         15         E65          A           Hypo             78
# 51         16         E65          A       Temporal             90
# 52         17         E65          A       Parietal              7
# 53         18         E65          A           Pons             19
# 54         19         E65          A     Cerebellum             31
# 55         20         E65          A       Midbrain             43
# 56         21         E65          B       Thalamus             55
# 57         22         E65          B   Hypothalamus             67
# 58         23         E65          A    Hippocampus             79
# 59         24         E65          B            LGE             91
# 60         25         E65          B     Cerebellum              8
# 61         26         E65          B       Temporal             20
# 62         27         E65          B       Parietal             32
# 63         28         E65          B         Somato             44
# 64         29         E65          B    Hippocampus             56
# 65         30         E65          B        Choroid             68
# 66         31         E65          A        Choroid             80
# 67         32         E65          B  Midbrain/Pons             92
#
#    P7IlluminaIndexNumber             fullname
# 36                 3,4,5            E65_A_PFC
# 37                 3,4,5        E65_A_Motor-1
# 38                 3,4,5             E65_A_V1
# 39                 3,4,5            E65_A_MGE
# 40                 3,4,5            E65_B_PFC
# 41                 3,4,5        E65_B_Motor-1
# 42                 3,4,5             E65_B_V1
# 43                 3,4,5            E65_B_MGE
# 44                 3,4,5        E65_A_Motor-2
# 45                 3,4,5        E65_B_Motor-2
# 46                 3,4,5            E65_A_LGE
# 47                 3,4,5            E65_A_CGE
# 48                 3,4,5         E65_A_Somato
# 49                 3,4,5           E65_A_Thal
# 50                 3,4,5           E65_A_Hypo
# 51                 3,4,5       E65_A_Temporal
# 52                 3,4,5       E65_A_Parietal
# 53                 3,4,5           E65_A_Pons
# 54                 3,4,5     E65_A_Cerebellum
# 55                 3,4,5       E65_A_Midbrain
# 56                 3,4,5       E65_B_Thalamus
# 57                 3,4,5   E65_B_Hypothalamus
# 58                 3,4,5    E65_A_Hippocampus
# 59                 3,4,5            E65_B_LGE
# 60                 3,4,5     E65_B_Cerebellum
# 61                 3,4,5       E65_B_Temporal
# 62                 3,4,5       E65_B_Parietal
# 63                 3,4,5         E65_B_Somato
# 64                 3,4,5    E65_B_Hippocampus
# 65                 3,4,5        E65_B_Choroid
# 66                 3,4,5        E65_A_Choroid
# 67                 3,4,5  E65_B_Midbrain/Pons
#    Unnamed: 0 Timepoint\n Individual        Sample Multiseq Index  \
# 0           1         E80        nan           PFC             13
# 1           2         E80        nan       Motor-1             14
# 2           3         E80        nan          Pons             15
# 3           4         E80        nan        Somato             16
# 4           5         E80        nan      Parietal             17
# 5           6         E80        nan      Temporal             18
# 6           7         E80        nan            V1             37
# 7           8         E80        nan         Hippo             38
# 8           9         E80        nan       Choroid             39
# 9          10         E80        nan           MGE             40
# 10         11         E80        nan           LGE             41
# 11         12         E80        nan           CGE             42
# 12         13         E80        nan      Thalamus             25
# 13         14         E80        nan  Hypothalamus             26
# 14         15         E80        nan      Midbrain             27
# 15         16         E80        nan    Cerebellum             28
#
#    P7IlluminaIndexNumber          fullname
# 0                      1           E80_PFC
# 1                      1       E80_Motor-1
# 2                      1          E80_Pons
# 3                      1        E80_Somato
# 4                      1      E80_Parietal
# 5                      1      E80_Temporal
# 6                      1            E80_V1
# 7                      1         E80_Hippo
# 8                      1       E80_Choroid
# 9                      1           E80_MGE
# 10                     1           E80_LGE
# 11                     1           E80_CGE
# 12                     1      E80_Thalamus
# 13                     1  E80_Hypothalamus
# 14                     1      E80_Midbrain
# 15                     1    E80_Cerebellum
#    Unnamed: 0 Timepoint\n Individual        Sample Multiseq Index  \
# 16          1         E90        nan           PFC              2
# 17          2         E90        nan       Motor-1             14
# 18          3         E90        nan       Motor-2             26
# 19          4         E90        nan        Somato             38
# 20          5         E90        nan      Parietal             50
# 21          6         E90        nan      Temporal             62
# 22          7         E90        nan            V1             74
# 23          8         E90        nan         Hippo             86
# 24          9         E90        nan       Choroid              3
# 25         10         E90        nan           MGE             15
# 26         11         E90        nan           LGE             27
# 27         12         E90        nan           CGE             39
# 28         13         E90        nan       Putamen             51
# 29         14         E90        nan        Septum             63
# 30         15         E90        nan      Thalamus             75
# 31         16         E90        nan  Hypothalamus             87
# 32         17         E90        nan      Midbrain             52
# 33         18         E90        nan    Cerebellum             64
# 34         19         E90        nan          Pons             76
# 35         20         E90        nan   E80Cultured             88
#
#    P7IlluminaIndexNumber          fullname
# 16                     2           E90_PFC
# 17                     2       E90_Motor-1
# 18                     2       E90_Motor-2
# 19                     2        E90_Somato
# 20                     2      E90_Parietal
# 21                     2      E90_Temporal
# 22                     2            E90_V1
# 23                     2         E90_Hippo
# 24                     2       E90_Choroid
# 25                     2           E90_MGE
# 26                     2           E90_LGE
# 27                     2           E90_CGE
# 28                     2       E90_Putamen
# 29                     2        E90_Septum
# 30                     2      E90_Thalamus
# 31                     2  E90_Hypothalamus
# 32                     2      E90_Midbrain
# 33                     2    E90_Cerebellum
# 34                     2          E90_Pons
# 35                     2   E90_E80Cultured

# %%
for s in sampletable.keys():
    data = [go.Bar(
        y=sampletable[s][1].value_counts().to_dense().keys(),
        x=sampletable[s][1].value_counts(),
        orientation='h',
        text="",
    )]
    layout = go.Layout(
    title=go.layout.Title(
        text=s,
        xref='paper',
        x=0
    ))
    fig = go.Figure(data=data, layout=layout)
    iplot(fig, show_link=False)
    print(sorted(Counter(sampletable[s][1]).keys()))
# Out:
# <div>
#
#
#             <div id="7cc4c198-3358-45f7-853f-3f2864b78c20" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7cc4c198-3358-45f7-853f-3f2864b78c20")) {
#                     Plotly.newPlot(
#                         '7cc4c198-3358-45f7-853f-3f2864b78c20',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "e4ae9df3-82c3-453b-a247-c168505533e0", "x": [2364, 469, 420, 321, 299, 279, 253, 228, 184, 168, 159, 158, 152, 146, 142, 125, 123, 114, 110, 109, 109, 109, 103, 91, 83, 80, 76, 73, 48, 41, 35, 26, 12, 11, 3, 1], "y": ["Negative", "E65_B_Motor-2", "Doublet", "E65_A_Temporal", "E65_A_V1", "E65_A_CGE", "E65_A_Somato", "E65_B_Parietal", "E65_B_MGE", "E65_B_PFC", "E65_A_PFC", "E65_B_Motor-1", "E65_A_Motor-1", "E65_A_LGE", "E65_A_Thal", "E65_B_V1", "E65_B_Somato", "E65_A_Parietal", "E65_A_Hypo", "E65_A_Motor-2", "E65_A_MGE", "E65_B_Temporal", "E65_B_Choroid", "E65_A_Hippocampus", "E65_A_Midbrain", "E65_A_Choroid", "E65_B_Thalamus", "E65_B_Cerebellum", "E65_B_LGE", "E65_A_Cerebellum", "E65_B_Hippocampus", "E65_A_Pons", "E65_B_Midbrain/Pons", "E65_B_Hypothalamus", "73", "93"]}],
#                         {"title": {"text": "E65-1", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7cc4c198-3358-45f7-853f-3f2864b78c20');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['73', '93', 'Doublet', 'E65_A_CGE', 'E65_A_Cerebellum', 'E65_A_Choroid', 'E65_A_Hippocampus', 'E65_A_Hypo', 'E65_A_LGE', 'E65_A_MGE', 'E65_A_Midbrain', 'E65_A_Motor-1', 'E65_A_Motor-2', 'E65_A_PFC', 'E65_A_Parietal', 'E65_A_Pons', 'E65_A_Somato', 'E65_A_Temporal', 'E65_A_Thal', 'E65_A_V1', 'E65_B_Cerebellum', 'E65_B_Choroid', 'E65_B_Hippocampus', 'E65_B_Hypothalamus', 'E65_B_LGE', 'E65_B_MGE', 'E65_B_Midbrain/Pons', 'E65_B_Motor-1', 'E65_B_Motor-2', 'E65_B_PFC', 'E65_B_Parietal', 'E65_B_Somato', 'E65_B_Temporal', 'E65_B_Thalamus', 'E65_B_V1', 'Negative']
# <div>
#
#
#             <div id="ada47755-69e2-4790-b394-dd6fbb0f66d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ada47755-69e2-4790-b394-dd6fbb0f66d2")) {
#                     Plotly.newPlot(
#                         'ada47755-69e2-4790-b394-dd6fbb0f66d2',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "e05d0804-3ce4-4a87-b0f2-6b07ccfe1382", "x": [4783, 4330, 645, 503, 372, 360, 324, 296, 266, 233, 210, 208, 208, 205, 205, 202, 181, 173, 173, 141, 133, 128, 127, 121, 117, 116, 111, 101, 94, 74, 72, 45, 30, 19, 17, 17, 9, 3, 3, 1, 1, 1, 1], "y": ["Negative", "Doublet", "E65_B_Motor-2", "E65_A_Temporal", "E65_A_Cerebellum", "E65_A_V1", "E65_A_CGE", "E65_A_Somato", "E65_B_Parietal", "E65_A_Motor-1", "E65_B_Motor-1", "E65_A_LGE", "E65_A_Hypo", "E65_B_MGE", "E65_B_Somato", "E65_B_PFC", "E65_B_V1", "E65_B_Choroid", "E65_A_PFC", "E65_A_Parietal", "E65_A_Thal", "E65_A_Midbrain", "E65_A_Motor-2", "E65_A_Hippocampus", "E65_A_MGE", "E65_B_Cerebellum", "E65_B_Temporal", "E65_B_Thalamus", "E65_A_Choroid", "E65_B_Hippocampus", "E65_B_LGE", "E65_A_Pons", "E65_B_Midbrain/Pons", "E65_B_Hypothalamus", "75", "74", "12", "73", "82", "46", "84", "23", "93"]}],
#                         {"title": {"text": "E65-2", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ada47755-69e2-4790-b394-dd6fbb0f66d2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['12', '23', '46', '73', '74', '75', '82', '84', '93', 'Doublet', 'E65_A_CGE', 'E65_A_Cerebellum', 'E65_A_Choroid', 'E65_A_Hippocampus', 'E65_A_Hypo', 'E65_A_LGE', 'E65_A_MGE', 'E65_A_Midbrain', 'E65_A_Motor-1', 'E65_A_Motor-2', 'E65_A_PFC', 'E65_A_Parietal', 'E65_A_Pons', 'E65_A_Somato', 'E65_A_Temporal', 'E65_A_Thal', 'E65_A_V1', 'E65_B_Cerebellum', 'E65_B_Choroid', 'E65_B_Hippocampus', 'E65_B_Hypothalamus', 'E65_B_LGE', 'E65_B_MGE', 'E65_B_Midbrain/Pons', 'E65_B_Motor-1', 'E65_B_Motor-2', 'E65_B_PFC', 'E65_B_Parietal', 'E65_B_Somato', 'E65_B_Temporal', 'E65_B_Thalamus', 'E65_B_V1', 'Negative']
# <div>
#
#
#             <div id="181f2ca7-0fb4-4136-8bae-faa06a6e0ed5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("181f2ca7-0fb4-4136-8bae-faa06a6e0ed5")) {
#                     Plotly.newPlot(
#                         '181f2ca7-0fb4-4136-8bae-faa06a6e0ed5',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "c6ecc069-4bd1-4033-aea2-4fddb22a692f", "x": [4575, 2086, 861, 588, 496, 469, 440, 397, 293, 281, 278, 276, 274, 272, 270, 264, 232, 232, 222, 212, 208, 198, 190, 173, 166, 146, 138, 125, 122, 119, 84, 43, 25, 23, 9, 6, 3, 1], "y": ["Negative", "Doublet", "E65_B_Motor-2", "E65_A_Temporal", "E65_A_CGE", "E65_A_V1", "E65_A_Somato", "E65_B_Parietal", "E65_B_PFC", "E65_A_Thal", "E65_B_MGE", "E65_A_LGE", "E65_B_Somato", "E65_A_Motor-1", "E65_A_Hypo", "E65_A_PFC", "E65_B_V1", "E65_B_Motor-1", "E65_B_Choroid", "E65_A_MGE", "E65_A_Parietal", "E65_A_Midbrain", "E65_B_Temporal", "E65_A_Hippocampus", "E65_A_Choroid", "E65_A_Motor-2", "E65_B_Thalamus", "E65_B_Cerebellum", "E65_B_Hippocampus", "E65_A_Cerebellum", "E65_B_LGE", "E65_A_Pons", "E65_B_Midbrain/Pons", "E65_B_Hypothalamus", "12", "82", "61", "93"]}],
#                         {"title": {"text": "E65-3", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('181f2ca7-0fb4-4136-8bae-faa06a6e0ed5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['12', '61', '82', '93', 'Doublet', 'E65_A_CGE', 'E65_A_Cerebellum', 'E65_A_Choroid', 'E65_A_Hippocampus', 'E65_A_Hypo', 'E65_A_LGE', 'E65_A_MGE', 'E65_A_Midbrain', 'E65_A_Motor-1', 'E65_A_Motor-2', 'E65_A_PFC', 'E65_A_Parietal', 'E65_A_Pons', 'E65_A_Somato', 'E65_A_Temporal', 'E65_A_Thal', 'E65_A_V1', 'E65_B_Cerebellum', 'E65_B_Choroid', 'E65_B_Hippocampus', 'E65_B_Hypothalamus', 'E65_B_LGE', 'E65_B_MGE', 'E65_B_Midbrain/Pons', 'E65_B_Motor-1', 'E65_B_Motor-2', 'E65_B_PFC', 'E65_B_Parietal', 'E65_B_Somato', 'E65_B_Temporal', 'E65_B_Thalamus', 'E65_B_V1', 'Negative']
# <div>
#
#
#             <div id="9dde0640-b057-4a33-99b9-dcb688780dd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9dde0640-b057-4a33-99b9-dcb688780dd7")) {
#                     Plotly.newPlot(
#                         '9dde0640-b057-4a33-99b9-dcb688780dd7',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "3de61704-3e27-4213-85d1-6872efb51da7", "x": [5716, 4842, 1033, 720, 496, 447, 438, 364, 344, 317, 248, 235, 228, 226, 212, 131, 122, 106], "y": ["Doublet", "Negative", "E80_CGE", "E80_Hypothalamus", "E80_Somato", "E80_Pons", "E80_Choroid", "E80_Midbrain", "E80_Motor-1", "E80_MGE", "E80_Cerebellum", "E80_LGE", "E80_Thalamus", "E80_Hippo", "E80_Parietal", "E80_Temporal", "E80_PFC", "E80_V1"]}],
#                         {"title": {"text": "E80", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9dde0640-b057-4a33-99b9-dcb688780dd7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['Doublet', 'E80_CGE', 'E80_Cerebellum', 'E80_Choroid', 'E80_Hippo', 'E80_Hypothalamus', 'E80_LGE', 'E80_MGE', 'E80_Midbrain', 'E80_Motor-1', 'E80_PFC', 'E80_Parietal', 'E80_Pons', 'E80_Somato', 'E80_Temporal', 'E80_Thalamus', 'E80_V1', 'Negative']
# <div>
#
#
#             <div id="7dfe21f3-5af5-4ced-a279-4bfccde6d85d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7dfe21f3-5af5-4ced-a279-4bfccde6d85d")) {
#                     Plotly.newPlot(
#                         '7dfe21f3-5af5-4ced-a279-4bfccde6d85d',
#                         [{"orientation": "h", "text": "", "type": "bar", "uid": "afd8a950-4544-44ec-9894-1097ae65c54c", "x": [3908, 2234, 1154, 778, 630, 531, 473, 470, 450, 442, 379, 371, 347, 306, 224, 201, 177, 133, 106, 54, 18, 12, 9, 6, 1], "y": ["Negative", "Doublet", "E90_Motor-2", "E90_MGE", "E90_Putamen", "E90_Choroid", "E90_LGE", "E90_Motor-1", "E90_Hypothalamus", "E90_Thalamus", "E90_CGE", "E90_E80Cultured", "E90_Somato", "E90_Hippo", "E90_PFC", "E90_Parietal", "E90_Cerebellum", "E90_Midbrain", "E90_Temporal", "E90_V1", "E90_Septum", "82", "46", "66", "53"]}],
#                         {"title": {"text": "E90", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('7dfe21f3-5af5-4ced-a279-4bfccde6d85d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# ['46', '53', '66', '82', 'Doublet', 'E90_CGE', 'E90_Cerebellum', 'E90_Choroid', 'E90_E80Cultured', 'E90_Hippo', 'E90_Hypothalamus', 'E90_LGE', 'E90_MGE', 'E90_Midbrain', 'E90_Motor-1', 'E90_Motor-2', 'E90_PFC', 'E90_Parietal', 'E90_Putamen', 'E90_Septum', 'E90_Somato', 'E90_Temporal', 'E90_Thalamus', 'E90_V1', 'Negative']

# %%
sampletable
# Out:
# {'E65-1':                                   1
#  AAACCCAGTACGAGCA          E65_A_LGE
#  AAACCCAGTACTAAGA       E65_A_Somato
#  AAACCCATCAAAGAAC         E65_A_Thal
#  AAACCCATCTTCTGGC     E65_B_Parietal
#  AAACGAAAGAGCTGCA     E65_B_Parietal
#  AAACGAAAGCTGCCTG  E65_B_Hippocampus
#  AAACGAACACGGCGTT      E65_B_Motor-1
#  AAACGAACACTGGCCA          E65_A_LGE
#  AAACGAAGTTGCGTAT           E65_B_V1
#  AAACGAATCGATTCCC           E65_A_V1
#  AAACGAATCGTGGCTG          E65_B_MGE
#  AAACGAATCTGCCTCA       E65_A_Somato
#  AAACGCTAGAGATGCC      E65_A_Motor-1
#  AAACGCTAGATGCTTC          E65_B_PFC
#  AAACGCTAGGAAAGGT      E65_B_Motor-1
#  AAACGCTAGGCCCAAA     E65_A_Parietal
#  AAACGCTCAGGTGACA   E65_B_Cerebellum
#  AAACGCTTCCAGGACC            Doublet
#  AAACGCTTCTCATTTG       E65_A_Somato
#  AAACGCTTCTGTAAGC      E65_B_Motor-2
#  AAAGAACAGGCTGTAG      E65_B_Motor-1
#  AAAGAACGTACTCAAC            Doublet
#  AAAGAACGTTTCCATT     E65_A_Temporal
#  AAAGAACTCACGGACC            Doublet
#  AAAGGATAGAGCAGCT      E65_B_Motor-2
#  AAAGGATAGATGAACT            Doublet
#  AAAGGATAGATTGGGC          E65_A_LGE
#  AAAGGATAGCACTGGA     E65_A_Temporal
#  AAAGGATAGCGCCATC      E65_A_Motor-1
#  AAAGGATAGCTGAGTG   E65_B_Cerebellum
#  ...                             ...
#  TATTTCGAGGTACAGC           Negative
#  TCAGCCTAGCAGGTCA           Negative
#  TCAGCCTCACGCTGCA           Negative
#  TCAGTCCTCTGGGATT           Negative
#  TCAGTTTGTGCATTAC           Negative
#  TCAGTTTTCAACGAGG           Negative
#  TCATATCGTTGTCTAG           Negative
#  TCATGCCTCTACCCAC           Negative
#  TCGACGGAGAAACACT           Negative
#  TCGCTCAGTATCGCGC           Negative
#  TCTATACGTCCATACA           Negative
#  TCTGCCACACGACGCT           Negative
#  TGAGGGACACTCCCTA           Negative
#  TGAGGTTGTCTCTCTG           Negative
#  TGATTCTAGAGAGCAA           Negative
#  TGCAGTAGTCGGTACC           Negative
#  TGCATCCCACGTAACT           Negative
#  TGCATGAGTGCAGTGA           Negative
#  TGCGACGGTTATTCTC           Negative
#  TGCTCGTAGTCTGTAC           Negative
#  TGCTGAAGTCATCGCG           Negative
#  TGCTTGCTCGGTGCAC           Negative
#  TGGATCAGTCGCACAC           Negative
#  TGGTAGTGTGAGTTTC           Negative
#  TGGTAGTTCACTTATC           Negative
#  TGTAACGGTGAACGGT           Negative
#  TGTCCCAAGACTCGAG           Negative
#  TGTTGGACAACAGATA           Negative
#  TTCAATCCAACGCATT           Negative
#  TTGGGTACAAAGGTTA           Negative
#
#  [7224 rows x 1 columns], 'E65-2':                                   1
#  AAACCCAAGACATATG     E65_B_Parietal
#  AAACCCAAGACCATGG      E65_B_Motor-2
#  AAACCCAAGACGTCCC            Doublet
#  AAACCCAAGACTGTTC          E65_A_CGE
#  AAACCCAAGCACACCC            Doublet
#  AAACCCAAGCCGAACA            Doublet
#  AAACCCAAGGTACATA            Doublet
#  AAACCCAAGTCACGAG            Doublet
#  AAACCCAAGTGGTTAA       E65_A_Somato
#  AAACCCAAGTTGCATC  E65_B_Hippocampus
#  AAACCCACAAGACCGA            Doublet
#  AAACCCACACGGCGTT            Doublet
#  AAACCCAGTCTACACA      E65_A_Motor-2
#  AAACCCAGTGAGACCA            Doublet
#  AAACCCAGTGGAGAAA      E65_B_Motor-2
#  AAACCCATCCACCCTA            Doublet
#  AAACCCATCCCTCGTA            Doublet
#  AAACCCATCCTAAACG            Doublet
#  AAACCCATCCTATTGT          E65_B_PFC
#  AAACCCATCCTCACCA          E65_A_MGE
#  AAACGAAAGAATCGCG      E65_B_Motor-2
#  AAACGAAAGCCGTCGT          E65_A_LGE
#  AAACGAAAGTAAATGC           E65_B_V1
#  AAACGAACACACAGAG            Doublet
#  AAACGAACACCTCTGT            Doublet
#  AAACGAACAGGTCAAG            Doublet
#  AAACGAAGTAACTTCG          E65_A_CGE
#  AAACGAAGTACCCGCA            Doublet
#  AAACGAAGTAGTCTGT       E65_A_Somato
#  AAACGAAGTCTTGGTA            Doublet
#  ...                             ...
#  TGGTACATCTTCACAT           Negative
#  TGGTAGTAGCTCGGCT           Negative
#  TGGTAGTTCTAGCCAA           Negative
#  TGGTGATCAACCCTAA           Negative
#  TGGTGATGTTCCGGTG           Negative
#  TGGTGATTCAACGTGT           Negative
#  TGGTGATTCTGGCCGA           Negative
#  TGTAACGTCGGAGTAG           Negative
#  TGTAAGCCATCTTCGC           Negative
#  TGTCAGAAGGACGCTA           Negative
#  TGTCAGAAGGTTAAAC           Negative
#  TGTCCCACAGCCTTCT           Negative
#  TGTGATGTCGGATACT           Negative
#  TGTGCGGCAGATCATC           Negative
#  TGTGCGGGTGTCCAAT           Negative
#  TGTGCGGGTGTCCATA           Negative
#  TGTGTGAGTACTCAAC           Negative
#  TGTTACTAGATCCTAC           Negative
#  TGTTACTGTGTAGTGG           Negative
#  TGTTCCGCATGTTCGA           Negative
#  TGTTGAGCACGCCAGT           Negative
#  TTCAGGAAGGACCCAA           Negative
#  TTCCACGCACGAAAGC           Negative
#  TTGAACGCAGTAGAAT           Negative
#  TTGACCCTCCCAGGCA           Negative
#  TTGAGTGTCCACTGGG           Negative
#  TTGATGGAGCCTAGGA           Negative
#  TTGCATTAGACGGTCA           Negative
#  TTGCTGCGTACCTGTA           Negative
#  TTGGGTACAGTGGGTA           Negative
#
#  [15359 rows x 1 columns], 'E65-3':                                1
#  AAACCCACACTGTGTA         Doublet
#  AAACCCACAGATCCAT  E65_A_Midbrain
#  AAACCCACAGATGCGA       E65_A_PFC
#  AAACCCACAGCCGGTT   E65_B_Motor-2
#  AAACCCATCCATCTGC       E65_B_PFC
#  AAACCCATCCTAGCCT  E65_A_Temporal
#  AAACCCATCCTGGGAC       E65_A_CGE
#  AAACCCATCTCTCTAA        E65_A_V1
#  AAACGAAAGCGGTATG    E65_A_Somato
#  AAACGAACACGCAAAG   E65_B_Choroid
#  AAACGAACAGACACCC         Doublet
#  AAACGAACATACAGCT       E65_A_PFC
#  AAACGAAGTATGAGGC        E65_B_V1
#  AAACGAAGTCCAAGAG  E65_B_Parietal
#  AAACGAAGTGCATGAG   E65_B_Motor-2
#  AAACGAAGTGCCTATA  E65_A_Midbrain
#  AAACGAATCTAGTGAC   E65_B_Choroid
#  AAACGCTAGACCAAAT   E65_A_Choroid
#  AAACGCTAGATGCCGA    E65_A_Somato
#  AAACGCTAGCCTGCCA         Doublet
#  AAACGCTAGCGGGTAT   E65_B_Motor-2
#  AAACGCTAGCTTAAGA        E65_A_V1
#  AAACGCTAGGTATTGA         Doublet
#  AAACGCTCACCCATAA       E65_B_MGE
#  AAACGCTCACCGGCTA  E65_A_Temporal
#  AAACGCTCACGCTGCA       E65_A_CGE
#  AAACGCTCACGGTGCT        E65_B_V1
#  AAACGCTCAGCAAGAC   E65_B_Choroid
#  AAACGCTCAGTCAGAG   E65_B_Choroid
#  AAACGCTCAGTTGTCA  E65_A_Temporal
#  ...                          ...
#  TGCGATACAGCTGTCG        Negative
#  TGCGGCAGTCCCTAAA        Negative
#  TGCGGGTGTGCAATAA        Negative
#  TGCTCGTCAGAGACTG        Negative
#  TGCTTGCGTTCCTACC        Negative
#  TGGAACTAGCTTAAGA        Negative
#  TGGAGGACATAAGCAA        Negative
#  TGGATGTAGCACTAGG        Negative
#  TGGGAAGGTGGAACAC        Negative
#  TGGGAAGTCGAGTCCG        Negative
#  TGGGCGTCAATTGCTG        Negative
#  TGGGCGTCAGGCAATG        Negative
#  TGGGCTGAGGGACCAT        Negative
#  TGGGCTGAGTTCAACC        Negative
#  TGGGCTGCAATTCTTC        Negative
#  TGGTGATAGTAGCCAG        Negative
#  TGGTTAGGTTGGGACA        Negative
#  TGGTTAGTCACCCTGT        Negative
#  TGTAGACTCATGCCAA        Negative
#  TGTCCACGTCAACCAT        Negative
#  TGTCCCAGTGATATAG        Negative
#  TGTGATGTCCCAGTGG        Negative
#  TGTGTGAAGAAGCGCT        Negative
#  TTACGCCAGGGCAGGA        Negative
#  TTCCTAACAAAGGCAC        Negative
#  TTCTCTCGTATGTCCA        Negative
#  TTCTGTAAGGTCCTGC        Negative
#  TTGGGCGCAATAACGA        Negative
#  TTGGGCGCACCATTCC        Negative
#  TTGTGGAAGATGACCG        Negative
#
#  [14797 rows x 1 columns], 'E80':                                  1
#  AAACCCAAGCGACTAG           E80_CGE
#  AAACCCAAGCTCCGAC           Doublet
#  AAACCCAAGGCGCTTC          E80_Pons
#  AAACCCAAGGTCCAGA           Doublet
#  AAACCCACAATTAGGA  E80_Hypothalamus
#  AAACCCACATCCGTGG          E80_Pons
#  AAACCCACATGTGTCA           Doublet
#  AAACCCAGTACGACAG           Doublet
#  AAACCCAGTAGACACG           Doublet
#  AAACCCAGTATTGACC           Doublet
#  AAACCCAGTTTCGTTT      E80_Midbrain
#  AAACCCATCAAACTGC        E80_Somato
#  AAACCCATCAATCCAG  E80_Hypothalamus
#  AAACCCATCATGTCTT       E80_Motor-1
#  AAACCCATCTTAAGGC           Doublet
#  AAACGAAAGACCATAA           E80_CGE
#  AAACGAAAGGAAACGA           Doublet
#  AAACGAAAGGGCCCTT           E80_LGE
#  AAACGAAAGTCTTCCC           Doublet
#  AAACGAACAAGTATCC           E80_PFC
#  AAACGAACACGACTAT           Doublet
#  AAACGAACAGCAGTAG           Doublet
#  AAACGAACATATTCGG            E80_V1
#  AAACGAAGTAACATCC           Doublet
#  AAACGAAGTAGAAACT      E80_Temporal
#  AAACGAAGTCACCACG           E80_CGE
#  AAACGAAGTCCTCATC        E80_Somato
#  AAACGAAGTGCATTTG           Doublet
#  AAACGAAGTGGGCTTC        E80_Somato
#  AAACGCTAGAGTTGCG           Doublet
#  ...                            ...
#  GGGCCATAGGGATCTG          Negative
#  GGTGGCTCACTGAGTT          Negative
#  GTAATGCTCCATTGTT          Negative
#  GTACAGTAGCTGACCC          Negative
#  GTCGTAATCCTTGGAA          Negative
#  GTCTGTCTCCATCCGT          Negative
#  GTTAGACAGGTTGGAC          Negative
#  TAGATCGGTTGCATCA          Negative
#  TAGCACAAGTTGTCGT          Negative
#  TCAGCAACAATGTCAC          Negative
#  TCGTAGAAGGATTTGA          Negative
#  TGAGGTTAGGTATTGA          Negative
#  TGCCGAGGTGGATTTC          Negative
#  TGCGGGTCATTGCTGA          Negative
#  TGGAGAGTCCATTCGC          Negative
#  TGGAGGAGTTGCACGC          Negative
#  TGGGATTCAACCGACC          Negative
#  TGGGCGTCAAATAGCA          Negative
#  TGGTACAGTAGTGGCA          Negative
#  TGGTTAGTCATAGCAC          Negative
#  TGTAAGCTCTAGCATG          Negative
#  TGTCCCACACCAATTG          Negative
#  TGTGTGAAGCACTGGA          Negative
#  TGTGTGAAGGGTGGGA          Negative
#  TGTTCATGTTAGTTCG          Negative
#  TTAGGCACAACGATTC          Negative
#  TTCACGCAGGAAAGAC          Negative
#  TTCCAATCATATCTGG          Negative
#  TTCTGTAGTCTGATAC          Negative
#  TTGGGTAGTGAATGTA          Negative
#
#  [16225 rows x 1 columns], 'E90':                                  1
#  AAACCCAAGATAGTCA       E90_Motor-2
#  AAACCCAAGATGTTAG      E90_Thalamus
#  AAACCCAAGCCTCTTC           E90_LGE
#  AAACCCAAGTCCGCCA   E90_E80Cultured
#  AAACCCACACTTACAG       E90_Putamen
#  AAACCCACAGTCTACA       E90_Putamen
#  AAACCCAGTATCACGT       E90_Motor-2
#  AAACCCAGTCTCAAGT           E90_CGE
#  AAACCCAGTGAGAACC           E90_MGE
#  AAACCCAGTGGTCTCG      E90_Temporal
#  AAACCCAGTGTGTACT       E90_Motor-1
#  AAACCCAGTGTTATCG           Doublet
#  AAACCCAGTTCGGTAT           Doublet
#  AAACCCAGTTGACTGT           E90_CGE
#  AAACCCATCCATACAG       E90_Motor-2
#  AAACCCATCGCAATTG       E90_Motor-2
#  AAACGAAAGCACTAGG       E90_Putamen
#  AAACGAAAGCCGAACA  E90_Hypothalamus
#  AAACGAAAGGATATGT           Doublet
#  AAACGAACACGGGCTT       E90_Motor-1
#  AAACGAACAGTTTGGT           E90_LGE
#  AAACGAAGTATCGAGG        E90_Somato
#  AAACGAAGTCCCGGTA           E90_CGE
#  AAACGAAGTTGCTTGA       E90_Choroid
#  AAACGAATCCCTCATG       E90_Motor-2
#  AAACGAATCGTGGGTC           E90_MGE
#  AAACGCTCAGGTGACA       E90_Choroid
#  AAACGCTGTAACAAGT           Doublet
#  AAACGCTGTACCGGCT           Doublet
#  AAACGCTGTCTTACAG       E90_Motor-2
#  ...                            ...
#  TGTGCGGAGGATTTGA          Negative
#  TGTGTGAAGCTAGAGC          Negative
#  TGTTCATAGATTGTGA          Negative
#  TGTTCTACATAAGCAA          Negative
#  TGTTGGACATGGCTAT          Negative
#  TTACAGGAGGGTAGCT          Negative
#  TTAGGCAAGAAGGTAG          Negative
#  TTCAATCAGAGAGTTT          Negative
#  TTCAATCAGTGGTCAG          Negative
#  TTCAGGAAGAAGGATG          Negative
#  TTCCACGAGGGCGAGA          Negative
#  TTCCACGGTGATATAG          Negative
#  TTCCTAAAGTGATGGC          Negative
#  TTCCTAAGTTAAGGGC          Negative
#  TTCGATTAGCCAACCC          Negative
#  TTGAACGAGTGTAGAT          Negative
#  TTGAACGCAAGTGACG          Negative
#  TTGACCCCAAGGATGC          Negative
#  TTGAGTGAGGTGAGCT          Negative
#  TTGCCTGTCAATCCGA          Negative
#  TTGCGTCTCGAAGCCC          Negative
#  TTGCTGCAGAAGCTCG          Negative
#  TTGCTGCGTACAATAG          Negative
#  TTGGATGTCAGAATAG          Negative
#  TTGGATGTCGATACGT          Negative
#  TTGGGATGTGAGATCG          Negative
#  TTGGGATTCCCAAGTA          Negative
#  TTGGGTACAACTCCCT          Negative
#  TTGTGGATCATACGGT          Negative
#  TTGTTCAAGTAGGGTC          Negative
#
#  [13414 rows x 1 columns]}

# %%
adata = sc.read_10x_mtx('/home/mt/Downloads/macaque2final/E65-2019A_AND_E65-2019B_MULTI-SEQ_1_Out/outs/filtered_feature_bc_matrix',cache=True)
adata.obs.index=[re.sub("-1","",x) for x in adata.obs.index]
# Out:
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E65-2019A_AND_E65-2019B_MULTI-SEQ_1_Out-outs-filtered_feature_bc_matrix-matrix.h5ad

# %%
adata
sampletable['E65-1'].columns=['region']
#ta.obs=adata.obs.join(sampletable['E65-1'])
adata.obs.insert(0,'region',sampletable['E65-1'].loc[adata.obs.index,'region'])
#print(adata.obs)
# Out:
# /home/mt/code/utils/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1017: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike

# %%
adata.var_names_make_unique()

mito_genes = [name for name in adata.var_names if name in ['ND1','ND2','ND4L','ND4','ND5','ND6','ATP6','ATP8','CYTB','COX1','COX2','COX3'] or 'MT-' in name]
ribo_genes = [name for name in adata.var_names if name.startswith('RPS') or name.startswith('RPL') ]

adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
adata.obs['percent_ribo'] = np.sum(
    adata[:, ribo_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1).A1
#scanpy.api.pp.filter_genes_dispersion(adata,n_top_genes=np.sum(np.sum(adata.X, axis=0)>0))
sc.pp.filter_genes(adata, min_cells=20,inplace=True)
sc.pp.filter_cells(adata,min_genes=400)
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)
# Out:
# filtered out 18300 genes that are detected in less than 20 cells
# ... storing 'region' as categorical
# filtered out 319 cells that have less than 400 genes expressed
# ... storing 'feature_types' as categorical

# %%
def tp_format_macaque(name):
    if isinstance(name, str):
        searched=re.search("E[0-9]+",name)
        if searched is None:
            return('nan')
        tp=re.sub("^E","",searched.group(0))
        tp=float(tp)
        return(tp)
    else:
        return('nan')

def region_format_macaque(name):
    if isinstance(name, str):
        region=re.sub('E[0-9]+',"",name)
        region=re.sub("^_","",region)
        if '_' not in name:
            return('nan')
        spl=region.split('_')
        if len(spl) < 1:
            return('nan')
        region=spl[len(spl)-1]
    else:
        region='nan'
    return(region)

adata.obs.insert(0, 'simpleregion',[re.sub('_','',x[x.rfind('_'):]) if '_' in x else x for x in adata.obs['region']])
adata.obs.insert(0, 'tp',[tp_format_macaque(x) for x in adata.obs['region']])
adata.obs.insert(0, 'ActualRegion',[region_format_macaque(x) for x in adata.obs['region']])

# %%
adata.obs
# Out:
#                  ActualRegion   tp simpleregion             region  \
# AAACCCAGTACCCAGC          nan  nan          nan                nan
# AAACCCAGTACGAGCA          LGE   65          LGE          E65_A_LGE
# AAACCCAGTACTAAGA       Somato   65       Somato       E65_A_Somato
# AAACCCATCAAAGAAC         Thal   65         Thal         E65_A_Thal
# AAACCCATCTTCTGGC     Parietal   65     Parietal     E65_B_Parietal
# AAACGAAAGAGCTGCA     Parietal   65     Parietal     E65_B_Parietal
# AAACGAAAGCTGCCTG  Hippocampus   65  Hippocampus  E65_B_Hippocampus
# AAACGAACACGGCGTT      Motor-1   65      Motor-1      E65_B_Motor-1
# AAACGAACACTGGCCA          LGE   65          LGE          E65_A_LGE
# AAACGAAGTTGCGTAT           V1   65           V1           E65_B_V1
# AAACGAATCGATTCCC           V1   65           V1           E65_A_V1
# AAACGAATCGTGGCTG          MGE   65          MGE          E65_B_MGE
# AAACGAATCTGCCTCA       Somato   65       Somato       E65_A_Somato
# AAACGCTAGAGATGCC      Motor-1   65      Motor-1      E65_A_Motor-1
# AAACGCTAGATGCTTC          PFC   65          PFC          E65_B_PFC
# AAACGCTAGGAAAGGT      Motor-1   65      Motor-1      E65_B_Motor-1
# AAACGCTAGGCCCAAA     Parietal   65     Parietal     E65_A_Parietal
# AAACGCTCAGGTGACA   Cerebellum   65   Cerebellum   E65_B_Cerebellum
# AAACGCTTCCAGGACC          nan  nan      Doublet            Doublet
# AAACGCTTCTCATTTG       Somato   65       Somato       E65_A_Somato
# AAACGCTTCTGTAAGC      Motor-2   65      Motor-2      E65_B_Motor-2
# AAAGAACAGGCTGTAG      Motor-1   65      Motor-1      E65_B_Motor-1
# AAAGAACGTACTCAAC          nan  nan      Doublet            Doublet
# AAAGAACGTTTCCATT     Temporal   65     Temporal     E65_A_Temporal
# AAAGAACTCACGGACC          nan  nan      Doublet            Doublet
# AAAGGATAGAGCAGCT      Motor-2   65      Motor-2      E65_B_Motor-2
# AAAGGATAGATGAACT          nan  nan      Doublet            Doublet
# AAAGGATAGATTGGGC          LGE   65          LGE          E65_A_LGE
# AAAGGATAGCACTGGA     Temporal   65     Temporal     E65_A_Temporal
# AAAGGATAGCGCCATC      Motor-1   65      Motor-1      E65_A_Motor-1
# ...                       ...  ...          ...                ...
# TTTGACTTCATGTCAG          nan  nan     Negative           Negative
# TTTGACTTCTGGGCAC          nan  nan     Negative           Negative
# TTTGATCAGACATCCT          nan  nan     Negative           Negative
# TTTGATCAGAGTCACG          nan  nan     Negative           Negative
# TTTGATCCAAAGGAGA          nan  nan     Negative           Negative
# TTTGATCCAAGTCATC          nan  nan     Negative           Negative
# TTTGATCGTCTGTGCG          nan  nan     Negative           Negative
# TTTGATCTCCCAACTC          nan  nan     Negative           Negative
# TTTGATCTCGTCGATA          nan  nan     Negative           Negative
# TTTGATCTCTATCGGA          nan  nan     Negative           Negative
# TTTGATCTCTTGAACG          nan  nan     Negative           Negative
# TTTGGAGCAAAGTATG          nan  nan     Negative           Negative
# TTTGGAGGTTATCTGG          nan  nan     Negative           Negative
# TTTGGAGTCCCTTGTG          nan  nan     Negative           Negative
# TTTGGTTAGAGTACCG          nan  nan     Negative           Negative
# TTTGGTTAGGGTTAAT          nan  nan     Negative           Negative
# TTTGGTTCAACCAGAG          nan  nan     Negative           Negative
# TTTGGTTGTTCTCCCA          nan  nan     Negative           Negative
# TTTGGTTTCGCGTGCA          nan  nan     Negative           Negative
# TTTGTTGAGCTATCCA          nan  nan     Negative           Negative
# TTTGTTGAGGATAATC          nan  nan     Negative           Negative
# TTTGTTGAGTCATGCT          nan  nan     Negative           Negative
# TTTGTTGCAATGGGTG          nan  nan     Negative           Negative
# TTTGTTGCATCATCCC          nan  nan     Negative           Negative
# TTTGTTGCATCGTGGC          nan  nan     Negative           Negative
# TTTGTTGGTCACGCTG          nan  nan     Negative           Negative
# TTTGTTGGTTTACCAG          nan  nan     Negative           Negative
# TTTGTTGTCACCTCGT          nan  nan     Negative           Negative
# TTTGTTGTCGCCATAA          nan  nan     Negative           Negative
# TTTGTTGTCGCTCTAC          nan  nan     Negative           Negative
#
#                   percent_mito  percent_ribo  n_counts  n_genes
# AAACCCAGTACCCAGC      0.035250      0.153370    1617.0      820
# AAACCCAGTACGAGCA      0.050774      0.146749    1615.0      826
# AAACCCAGTACTAAGA      0.042857      0.120000    1400.0      791
# AAACCCATCAAAGAAC      0.073302      0.056490    2974.0     1488
# AAACCCATCTTCTGGC      0.069971      0.156463    2058.0     1011
# AAACGAAAGAGCTGCA      0.118197      0.119898    2352.0     1087
# AAACGAAAGCTGCCTG      0.188178      0.010493    2859.0      873
# AAACGAACACGGCGTT      0.088769      0.142569    1487.0      751
# AAACGAACACTGGCCA      0.057993      0.131488    7225.0     2399
# AAACGAAGTTGCGTAT      0.094488      0.105996    1651.0      868
# AAACGAATCGATTCCC      0.065092      0.153809    2074.0     1002
# AAACGAATCGTGGCTG      0.052821      0.094232    9466.0     3038
# AAACGAATCTGCCTCA      0.039709      0.129298    2065.0     1026
# AAACGCTAGAGATGCC      0.067537      0.092509    1762.0      980
# AAACGCTAGATGCTTC      0.076023      0.129630    2052.0      986
# AAACGCTAGGAAAGGT      0.206978      0.029231    2121.0     1035
# AAACGCTAGGCCCAAA      0.046718      0.154249    2483.0     1209
# AAACGCTCAGGTGACA      0.127437      0.087744    1436.0      730
# AAACGCTTCCAGGACC      0.066399      0.085528    7214.0     2597
# AAACGCTTCTCATTTG      0.017127      0.126546    1051.0      650
# AAACGCTTCTGTAAGC      0.062105      0.118116    4267.0     1705
# AAAGAACAGGCTGTAG      0.128450      0.137284    2717.0     1161
# AAAGAACGTACTCAAC      0.100809      0.083237    4325.0     1854
# AAAGAACGTTTCCATT      0.070561      0.122087    3047.0     1369
# AAAGAACTCACGGACC      0.076036      0.075676    5550.0     1994
# AAAGGATAGAGCAGCT      0.110166      0.081667    2351.0     1186
# AAAGGATAGATGAACT      0.094118      0.065650    6885.0     2671
# AAAGGATAGATTGGGC      0.060295      0.172144    3317.0     1396
# AAAGGATAGCACTGGA      0.062246      0.132624    3197.0     1360
# AAAGGATAGCGCCATC      0.114769      0.093861    2248.0     1072
# ...                        ...           ...       ...      ...
# TTTGACTTCATGTCAG      0.087476      0.093690    2092.0     1047
# TTTGACTTCTGGGCAC      0.056604      0.089623     636.0      449
# TTTGATCAGACATCCT      0.056073      0.121279    5475.0     2107
# TTTGATCAGAGTCACG      0.126852      0.099383    3240.0     1382
# TTTGATCCAAAGGAGA      0.075603      0.125124    3029.0     1314
# TTTGATCCAAGTCATC      0.074792      0.099121    4439.0     1832
# TTTGATCGTCTGTGCG      0.083414      0.147541    2074.0     1038
# TTTGATCTCCCAACTC      0.055028      0.069279    7578.0     3027
# TTTGATCTCGTCGATA      0.070909      0.093818    2750.0     1398
# TTTGATCTCTATCGGA      0.034996      0.129312    4029.0     1438
# TTTGATCTCTTGAACG      0.077522      0.103051    3212.0     1355
# TTTGGAGCAAAGTATG      0.138981      0.099272    1511.0      773
# TTTGGAGGTTATCTGG      0.054026      0.140119    2869.0     1347
# TTTGGAGTCCCTTGTG      0.100637      0.112420    3140.0     1297
# TTTGGTTAGAGTACCG      0.099564      0.120684    2983.0     1228
# TTTGGTTAGGGTTAAT      0.061777      0.125380    3286.0     1565
# TTTGGTTCAACCAGAG      0.116181      0.112945    3090.0     1386
# TTTGGTTGTTCTCCCA      0.051079      0.071955    7185.0     3023
# TTTGGTTTCGCGTGCA      0.093082      0.085220    3180.0     1511
# TTTGTTGAGCTATCCA      0.039722      0.101966    2442.0     1313
# TTTGTTGAGGATAATC      0.103620      0.041164    1409.0      796
# TTTGTTGAGTCATGCT      0.058550      0.121753    2579.0     1096
# TTTGTTGCAATGGGTG      0.085424      0.105006    8171.0     2052
# TTTGTTGCATCATCCC      0.080357      0.084239    2576.0     1330
# TTTGTTGCATCGTGGC      0.149240      0.020267    2171.0     1180
# TTTGTTGGTCACGCTG      0.056258      0.173620    4746.0     1888
# TTTGTTGGTTTACCAG      0.085746      0.140869    1796.0      870
# TTTGTTGTCACCTCGT      0.039910      0.142215    1779.0      892
# TTTGTTGTCGCCATAA      0.074897      0.072739    4633.0     2087
# TTTGTTGTCGCTCTAC      0.030159      0.118651    2520.0     1304
#
# [6906 rows x 8 columns]

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

sc.pp.log1p(adata)

sc.pp.highly_variable_genes(adata, n_top_genes=3000)
sc.pp.scale(adata, max_value=10)
#sc.pp.regress_out(adata,'n_counts')
# Out:
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)
# Out:
# Note that scikit-learn's randomized PCA might not be exactly reproducible across different computational platforms. For exact reproducibility, choose `svd_solver='arpack'.` This will likely become the Scanpy default in the future.
# computing PCA with n_comps = 50
# computing PCA on highly variable genes
#     finished (0:00:00.71)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished (0:00:05.57) --> added to `.uns['neighbors']`
#     'distances', distances for each pair of neighbors
#     'connectivities', weighted adjacency matrix
# computing UMAP
#     using 'X_pca' with n_pcs = 50
# /home/mt/code/utils/miniconda3/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning:
#
# Embedding a total of 2 separate connected components using meta-embedding (experimental)
#     finished (0:00:13.50) --> added
#     'X_umap', UMAP coordinates (adata.obsm)
# running Leiden clustering
#     finished (0:00:01.68) --> found 23 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical)

# %%
def cell_cycle_score(adata,save=False):
    s_genes=['MCM5', 'PCNA', 'TYMS', 'FEN1', 'MCM2', 'MCM4', 'RRM1', 'UNG', 'GINS2', 'MCM6', 'CDCA7', 'DTL', 'PRIM1', 'UHRF1', 'MLF1IP', 'HELLS', 'RFC2', 'RPA2', 'NASP', 'RAD51AP1', 'GMNN', 'WDR76', 'SLBP', 'CCNE2', 'UBR7', 'POLD3', 'MSH2', 'ATAD2', 'RAD51', 'RRM2', 'CDC45', 'CDC6', 'EXO1', 'TIPIN', 'DSCC1', 'BLM', 'CASP8AP2', 'USP1', 'CLSPN', 'POLA1', 'CHAF1B', 'BRIP1', 'E2F8']
    g2m_genes=['HMGB2', 'CDK1', 'NUSAP1', 'UBE2C', 'BIRC5', 'TPX2', 'TOP2A', 'NDC80', 'CKS2', 'NUF2', 'CKS1B', 'MKI67', 'TMPO', 'CENPF', 'TACC3', 'FAM64A', 'SMC4', 'CCNB2', 'CKAP2L', 'CKAP2', 'AURKB', 'BUB1', 'KIF11', 'ANP32E', 'TUBB4B', 'GTSE1', 'KIF20B', 'HJURP', 'CDCA3', 'HN1', 'CDC20', 'TTK', 'CDC25C', 'KIF2C', 'RANGAP1', 'NCAPD2', 'DLGAP5', 'CDCA2', 'CDCA8', 'ECT2', 'KIF23', 'HMMR', 'AURKA', 'PSRC1', 'ANLN', 'LBR', 'CKAP5', 'CENPE', 'CTCF', 'NEK2', 'G2E3', 'GAS2L3', 'CBX5', 'CENPA']
    sc.tl.score_genes_cell_cycle(adata,s_genes=s_genes,g2m_genes=g2m_genes)
    sc.pl.violin(adata, ['G2M_score','S_score'], groupby='leiden')
    if 'X_tsne' in adata.obsm.keys(): 
        sc.pl.tsne(adata, color=['G2M_score','S_score','phase','leiden'],save='_cc')
    sc.pl.umap(adata, color=['G2M_score','S_score','phase','leiden'],save='_cc')
    return(adata)
cell_cycle_score(adata)
# Out:
# calculating cell cycle phase
# computing score 'S_score'
# WARNING: gene: GINS2 is not in adata.var_names and will be ignored
# WARNING: gene: MLF1IP is not in adata.var_names and will be ignored
# WARNING: gene: NASP is not in adata.var_names and will be ignored
# WARNING: gene: RAD51 is not in adata.var_names and will be ignored
#     finished (0:00:01.66) --> added
#     'S_score', score of gene set (adata.obs)
# computing score 'G2M_score'
# WARNING: gene: HMGB2 is not in adata.var_names and will be ignored
# WARNING: gene: UBE2C is not in adata.var_names and will be ignored
# WARNING: gene: CKS2 is not in adata.var_names and will be ignored
# WARNING: gene: CKS1B is not in adata.var_names and will be ignored
# WARNING: gene: FAM64A is not in adata.var_names and will be ignored
# WARNING: gene: HN1 is not in adata.var_names and will be ignored
# ... storing 'ActualRegion' as categorical
# ... storing 'tp' as categorical
# ... storing 'simpleregion' as categorical
# ... storing 'phase' as categorical
#     finished (0:00:01.65) --> added
#     'G2M_score', score of gene set (adata.obs)
# -->     'phase', cell cycle phase (adata.obs)
# saving figure to file ./figures/umap_cc.pdf
# AnnData object with n_obs × n_vars = 6906 × 12507
#     obs: 'ActualRegion', 'tp', 'simpleregion', 'region', 'percent_mito', 'percent_ribo', 'n_counts', 'n_genes', 'leiden', 'S_score', 'G2M_score', 'phase'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'pca', 'neighbors', 'leiden', 'phase_colors', 'leiden_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
sc.pl.umap(adata, color=['leiden','phase','n_counts'])

# %%
sc.pl.umap(adata, color=['leiden','phase','n_counts','region'])
sc.pl.umap(adata, color=['region'])

# %%
sampleDirs=dict(zip(sampletable.keys(),['E65-2019A_AND_E65-2019B_MULTI-SEQ_1_Out',
                                        'E65-2019A_AND_E65-2019B_MULTI-SEQ_2_Out',
                                        'E65-2019A_AND_E65-2019B_MULTI-SEQ_3_Out',
                                        'E80-2019_MULTI-SEQ_Out',
                                       'E90-2019_MULTI-SEQ_Out']))

# %%
adatas=[]
for s in sampletable.keys():
    adata = sc.read_10x_mtx('/home/mt/Downloads/macaque2final/'+sampleDirs[s]+'/outs/filtered_feature_bc_matrix',cache=True)
    adata.obs.index=[re.sub("-1","",x) for x in adata.obs.index]
    sampletable[s].columns=['region']
    adata.obs.insert(0,'region',sampletable[s].loc[adata.obs.index,'region'])
    adatas.append(adata)
# Out:
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E65-2019A_AND_E65-2019B_MULTI-SEQ_1_Out-outs-filtered_feature_bc_matrix-matrix.h5ad
# /home/mt/code/utils/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1017: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E65-2019A_AND_E65-2019B_MULTI-SEQ_2_Out-outs-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E65-2019A_AND_E65-2019B_MULTI-SEQ_3_Out-outs-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E80-2019_MULTI-SEQ_Out-outs-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file /home/mt/Downloads/macaquecache/home-mt-Downloads-macaque2final-E90-2019_MULTI-SEQ_Out-outs-filtered_feature_bc_matrix-matrix.h5ad

# %%
adata=anndata.AnnData.concatenate(*adatas)

# %%
adata.write(os.path.expanduser("~/Downloads/MultiseqRaw.h5ad"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-c86baddb691c> in <module>
# ----> 1 [x if '_' in x else x for x in adata.obs['region']]
#
# <ipython-input-35-c86baddb691c> in <listcomp>(.0)
# ----> 1 [x if '_' in x else x for x in adata.obs['region']]
#
# TypeError: argument of type 'float' is not iterable

# %%
adata.obs.insert(0, 'simpleregion',[re.sub('_','',x[x.rfind('_'):]) if '_' in x else x for x in adata.obs['region']])
adata.obs.insert(0, 'tp',[tp_format_macaque(x) for x in adata.obs['region']])
adata.obs.insert(0, 'ActualRegion',[region_format_macaque(x) for x in adata.obs['region']])

# %%
adata.write(os.path.expanduser("~/Downloads/MultiseqRaw.h5ad"))
# Out:
# ... storing 'ActualRegion' as categorical
# ... storing 'tp' as categorical
# ... storing 'simpleregion' as categorical

# %%
adata.var_names_make_unique()

mito_genes = [name for name in adata.var_names if name in ['ND1','ND2','ND4L','ND4','ND5','ND6','ATP6','ATP8','CYTB','COX1','COX2','COX3'] or 'MT-' in name]
ribo_genes = [name for name in adata.var_names if name.startswith('RPS') or name.startswith('RPL') ]

adata.obs['percent_mito'] = np.sum(
    adata[:, mito_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
adata.obs['percent_ribo'] = np.sum(
    adata[:, ribo_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1
# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1).A1
#scanpy.api.pp.filter_genes_dispersion(adata,n_top_genes=np.sum(np.sum(adata.X, axis=0)>0))
sc.pp.filter_genes(adata, min_cells=20,inplace=True)
sc.pp.filter_cells(adata,min_genes=400)
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)

sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

sc.pp.log1p(adata)

sc.pp.highly_variable_genes(adata, n_top_genes=3000)
sc.pp.scale(adata, max_value=10)
#sc.pp.regress_out(adata,'n_counts')

sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.tl.leiden(adata)

# %%
#cell_cycle_score(adata)
sc.pl.umap(adata, color=['leiden','n_counts','region'])
sc.pl.umap(adata[[],:], color=['region'])
sc.pl.umap(adata, color=['simpleregion'])
sc.pl.umap(adata, color=['batch'])
sc.pl.umap(adata, color=['leiden'])

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='logreg')
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
df=pd.DataFrame({group + '_' + key[:1]: result[key][group] for group in groups for key in ['names', 'scores']})
df.to_csv(os.path.join(sc.settings.figdir,"leidenLogRegMarkers.csv"))

# %%
adata.obs.insert(0, 'simpleregion',[re.sub('_','',x[x.rfind('_'):]) if '_' in x else x for x in adata.obs['region']])

# %%
Counter(adata.obs['region'])

# %%
def marker_analysis(adata,variables=['leiden','region'],markerpath='https://docs.google.com/spreadsheets/d/e/2PACX-1vTz5a6QncpOOO-f3FHW2Edomn7YM5mOJu4z_y07OE3Q4TzcRr14iZuVyXWHv8rQuejzhhPlEBBH1y0V/pub?gid=1154528422&single=true&output=tsv'):
    sc.set_figure_params(color_map="Purples")
    import random
    markerpath=os.path.expanduser(markerpath)
    markers=pd.read_csv(markerpath,sep="\t",index_col=False)
    markers[markers.keys()[0]]=[str(x) for x in markers[markers.keys()[0]]]
    markers[markers.keys()[2]]=[str(x).split(',') for x in markers[markers.keys()[2]]]
    markers[markers.keys()[3]]=[str(x).split(';') for x in markers[markers.keys()[3]]]
    markers[markers.keys()[3]]=[[str(x).split(',') for x in y] for y in markers[markers.keys()[3]]]
    uniqueClasses=set([y for x in markers[markers.keys()[2]] for y in x if y!='nan'])
    uniqueSubClasses=set([z for x in markers[markers.keys()[3]] for y in x for z in y if z!='nan'])
    comboClasses=[]
    for i in range(markers.shape[0]):
        rowlist=[]
        for j in range(len(markers[markers.keys()[2]][i])):
            print(i)
            print(j)
            print(markers[markers.keys()[3]][i])
            print(markers[markers.keys()[3]][i][j])
            for k in markers[markers.keys()[3]][i][j]:
                rowlist.append(' '.join(filter(lambda x: x != 'nan',[k,markers[markers.keys()[2]][i][j]])))
        comboClasses.append(rowlist)
    markers['fullclass']=comboClasses
    markers.set_index(markers.keys()[0],inplace=True,drop=False)
    markers=markers.loc[ [x for x in markers[markers.keys()[0]] if x in adata.var_names],:]
    uniqueFullClasses=set([y for x in markers['fullclass'] for y in x if y!='nan'])
    from collections import defaultdict
    markerDict = defaultdict(list)

    for x in uniqueFullClasses:
        for y in markers[markers.keys()[0]]:
            if x in markers.loc[y,'fullclass']:
                markerDict[x].append(y)
    markerDictClass = defaultdict(list)
    for x in uniqueClasses:
        for y in markers[markers.keys()[0]]:
            if x in markers.loc[y,'fullclass']:
                markerDictClass[x].append(y)

    markerPlotGroups=[]
    for k in markerDict.keys():
        if len(markerDict[k])>1:
            print(k)
            print(len(markerDict[k]))
            sc.tl.score_genes(adata,gene_list=markerDict[k],score_name=k,gene_pool= markerDict[k]+random.sample(adata.var.index.tolist(),min(4000,adata.var.index.shape[0])))
            markerPlotGroups.append(k)
    adata.uns['marker_groups']=list(markerDict.keys())
    for tag in variables:
        pd.DataFrame(adata.obs.groupby(tag).describe()).to_csv(os.path.join(sc.settings.figdir, tag+"MarkerSumStats.csv"))

    if 'X_tsne' in adata.obsm.keys():
        sc.pl.tsne(adata, color=markerPlotGroups,save="_Marker_Group")
    sc.pl.umap(adata, color=markerPlotGroups,save="_Marker_Group")
    print(markerDict)
    #sc.pl.violin(adata, markerPlotGroups, groupby='leiden',save="_Marker_Group_violins")
    for i in markerDictClass:
        print(i)
        if 'X_tsne' in adata.obsm.keys():
            sc.pl.tsne(adata, color=sorted(markerDictClass[i]),save="_"+str(i)+"_Marker")
        sc.pl.umap(adata, color=sorted(markerDictClass[i]),save="_"+str(i)+"_Marker")
    return(adata)

marker_analysis(adata,variables=['leiden','region'])

# %%
markerpath='https://docs.google.com/spreadsheets/d/e/2PACX-1vTz5a6QncpOOO-f3FHW2Edomn7YM5mOJu4z_y07OE3Q4TzcRr14iZuVyXWHv8rQuejzhhPlEBBH1y0V/pub?gid=1154528422&single=true&output=tsv'
markerpath=os.path.expanduser(markerpath)
markers=pd.read_csv(markerpath,sep="\t",index_col=False)

# %%
markers
